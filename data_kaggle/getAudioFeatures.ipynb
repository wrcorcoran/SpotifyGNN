# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os
from dotenv import load_dotenv
from collections import defaultdict
from sklearn.preprocessing import MinMaxScaler
import json
import numpy as np
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
def get_client():
    load_dotenv(dotenv_path=".env")
    client_id = os.getenv("SPOTIFY_CLIENT_ID")
    client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")

    auth_manager = SpotifyClientCredentials(
        client_id=client_id, client_secret=client_secret, requests_timeout=5
    )
    sp = spotipy.Spotify(auth_manager=auth_manager)
    return sp
sp = get_client()

# %%
with open('components/id_to_ind.json', 'r') as f:
    artist_map = json.load(f)

# %%
artists = list(artist_map.keys())

# %%
artists
# Out:
# ['4q3ewBCX7sLwd24euuV69X',
#  '3TVXtAsR1Inumwj472S9r4',
#  '06HL4z0CvFAxyc27GXpf02',
#  '1Xyo4u8uXC1ZmMpatF05PJ',
#  '5K4W6rqBFWDnAN6FQUkS6x',
#  '3Nrfpe0tUJi4K4DXYWgMUX',
#  '1uNFoZAHBGtllmzznpCI3s',
#  '6eUKZXaKkcviH0Ku9w2n3V',
#  '7dGJo4pcD2V6oG8kP0tJRR',
#  '246dkjvS1zLTtiykXe5h60',
#  '1mcTU81TzQhprhouKaTkpq',
#  '5f7VJjfbwm532GiveGC0ZK',
#  '4MCBfE4596Uoi2O4DtmEMz',
#  '66CXWjxzNUsdJxJ2JdwvnR',
#  '6M2wZ9GZgrQXHCFfjv46we',
#  '53XhwfbYqKCa1cC15pYq2q',
#  '4gzpq5DPGxSnKTe4SA8HAU',
#  '2YZyLoL8N0Wb9xBt1NhZWg',
#  '6vWDO969PvNqNYHIOW5v0m',
#  '1vyhD5VmyZ7KMfW5gqLgo5',
#  '2LRoIwlKmHjgvigdNGBHNo',
#  '1Cs0zKBU1kc0i8ypK3B9ai',
#  '5cj0lLjcoR7YOSnhnX0Po5',
#  '1RyvyyTE3xzB2ZywiAwp0i',
#  '6qqNVTkY8uBg9cP3Jd7DAH',
#  '4VMYDCV2IEDYJArk749S6m',
#  '15UsOTVnJzReFVN1VCnxy4',
#  '0du5cEVh5yTK9QJze8zA0C',
#  '41MozSoPIsD1dJM0CLPjZF',
#  '5pKCCKE2ajJHZ9KAiaK11H',
#  '790FomKkXshlbRYZFtlgla',
#  '716NhGYqD1jl2wI1Qkgq36',
#  '00FQb4jTyendYWaN8pK0wa',
#  '7bXgB6jMjp9ATFy66eO08Z',
#  '0Y5tJX1MQlPlqiwlOH1tJY',
#  '0hCNtLu0JehylgoiP8L4Gh',
#  '1i8SpTcr7yvPOmcqrbnVXY',
#  '2R21vXR83lH98kGeO99Y66',
#  '7ltDVBr6mKbRvohxheJ9h1',
#  '1URnnhqYAYcrqrcwql10ft',
#  '4YRxDV8wJFPHPTeXepOstw',
#  '52iwsT98xCoGgiGntTiR7K',
#  '4O15NlyKLIASxsJ0PrXPfz',
#  '0EmeFodog0BfCgMzAIvKQp',
#  '04gDigrS5kc9YWfZHwBETP',
#  '1VPmR4DJC1PlOtd0IADAO0',
#  '7CajNmpbOovFoOoasH2HaY',
#  '7iK8PXO48WeuP03g8YR51W',
#  '55Aa2cqylxrFIXC767Z865',
#  '1McMsnEElThX1knmY4oliG',
#  '3MZsBdqDrRTJihTHQrO6Dq',
#  '6LuN9FCkKOj5PcnpouEgny',
#  '6l3HvQ5sa6mXTsMTB19rO5',
#  '50co4Is1HCEo8bhOyUWKpn',
#  '3PhoLpVuITZKcymswpck5b',
#  '1r4hJ1h58CWwUQe3MxPuau',
#  '2hlmm7s2ICUX0LVIhVFlZQ',
#  '1dfeR4HaWDbWqFHLkxsg1d',
#  '7wlFDEWiM5OoIAt8RSli8b',
#  '4V8LLVI7PbaPR0K2TGSxFF',
#  '0EFisYRi20PTADoJrifHrz',
#  '3hcs9uc56yIGFCSy9leWe7',
#  '4AK6F7OLvEQ5QYCBNiQWHq',
#  '4oUHIQIBe0LHzYfvXNW4QM',
#  '77SW9BnxLY8rJ0RciFqkHh',
#  '57vWImR43h4CaDao012Ofp',
#  '1HY2Jd0NmPuamShAr6KMms',
#  '1wRPtKGflJrBx9BmLsSwlU',
#  '329e4yvIujISKGKz1BZZbO',
#  '0tmwSHipWxN12fsoLcFU3B',
#  '5Pwc4xIPtQLFEnJriah9YJ',
#  '7hJcb9fa4alzcOq3EaNPoG',
#  '7n2wHs1TKAczGzO7Dd2rGr',
#  '1bAftSH8umNcGZ0uyV7LMg',
#  '26VFTg2z8YR0cCuwLzESi2',
#  '6AgTAQt8XS6jRWi4sX7w49',
#  '2wY79sveU1sp5g7SokKOiI',
#  '0eDvMgVFoNV3TpwtrVCoTj',
#  '64KEffDW9EtZ1y2vBYgq8T',
#  '5WUlDfRSoLAfcVSX1WnrxN',
#  '6VuMaDnrHyPL1p4EHjYLi7',
#  '4zCH9qm4R2DADamUHMCa6O',
#  '3nFkdlSjzX9mRTtwJOzDYB',
#  '3WrFJ7ztbogyGnTHbHJFl2',
#  '2h93pZq0e7k5yf4dywlkpM',
#  '1yR65psqiazQpeM79CcGh8',
#  '77ziqFxp5gaInVrF2lj4ht',
#  '4LLpKhyESsyAXpc4laK94U',
#  '6jJ0s89eD6GaHleKKya26X',
#  '2LIk90788K0zvyj2JJVwkJ',
#  '7tYKF4w9nC0nq9CsPZTHyP',
#  '181bsRPaVXVlUKXrxwZfHK',
#  '2o5jDhtHVPhrJdv3cEQ99Z',
#  '1DxLCyH42yaHKGK3cl5bvG',
#  '0QHgL1lAIqAw0HtD7YldmP',
#  '4r63FhuTkUYltbVAg5TQnk',
#  '0TnOYISbd1XYRBk9myaseg',
#  '0Q8NcsJwoCbZOHHW63su5S',
#  '137W8MRPWKqSmrBGDBFSop',
#  '4nDoRrQiYLoBzwC5BhVJzF',
#  '6Xgp2XMz1fhVYe7i6yNAax',
#  '7Gi6gjaWy3DxyilpF1a8Is',
#  '0C8ZW7ezQVs4URX5aX7Kqx',
#  '5C4PDR4LnhZTbVnKWXuDKD',
#  '7n2Ycct7Beij7Dj7meI4X0',
#  '3q7HBObVc0L8jNeTe5Gofh',
#  '5lwmRuXgjX8xIwlnauTZIP',
#  '699OTQXzgjhIYAHMy9RyPD',
#  '6XyY86QOPPrYVGvF9ch6wz',
#  '2tIP7SsRs7vjIcLrU85W8J',
#  '2kCcBybjl3SAtIcwdWpUe3',
#  '0pePYDrJGk8gqMRbXrLJC8',
#  '2ye2Wgw4gimLv2eAKyk1NB',
#  '1SupJlEpv7RS2tPNRaHViT',
#  '2nszmSgqreHSdJA3zWPyrW',
#  '6S2OmqARrzebs0tKUEyXyp',
#  '6jGMq4yGs7aQzuGsMgVgZR',
#  '7c0XG5cIJTrrAgEC3ULPiq',
#  '2RdwBSPQiwcmiDo9kixcl8',
#  '0XwVARXT135rw8lyw1EeWP',
#  '07YUOmWljBTXwIseAUd9TW',
#  '6TIYQ3jFPwQSRmorSezPxX',
#  '26dSoYclwsYLMAKD3tpOr4',
#  '28gNT5KBp7IjEOQoevXf9N',
#  '718COspgdWOnwOFpJHRZHS',
#  '46SHBwWsqBkxI7EeeBEQG7',
#  '3EiLUeyEcA6fbRPSHkG5kb',
#  '3wcj11K77LjEY1PkEazffa',
#  '1dKdetem2xEmjgvyymzytS',
#  '13ubrt8QOOCPljQ2FL1Kca',
#  '3fMbdgg4jU18AjLCKBhRSm',
#  '3p7PcrEHaaKLJnPUGOtRlT',
#  '7FNnA9vBm6EKceENgCGRMb',
#  '1elUiq4X7pxej6FRlrEzjM',
#  '4Uc8Dsxct0oMqx0P6i60ea',
#  '2IMZYfNi21MGqxopj9fWx8',
#  '0fA0VVWsXO9YnASrzqfmYu',
#  '7jVv8c5Fj3E9VhNjxT4snq',
#  '7pbDxGE6nQSZVfiFdq9lOL',
#  '64M6ah0SkkRsnPGtGiRAbb',
#  '5YGY8feqx7naU7z4HrwZM6',
#  '43ZHCT0cAZBISjO8DG9PnE',
#  '4SsVbpTthjScTS7U2hmr1X',
#  '07YZf4WDAMNwqr4jfgOZ8y',
#  '1yxSLGMDHlW21z4YXirZDS',
#  '7nqOGRxlXj7N2JYbgNEjYH',
#  '4fxd5Ee7UefO4CUXgwJ7IP',
#  '4yvcSjfu4PC0CYQyLy4wSq',
#  '5INjqkS1o8h1imAzPqGZBb',
#  '4kYSro6naA4h99UJvo89HB',
#  '56oDRnqbIiwx4mymNEv7dS',
#  '4tZwfgrHOc3mvqYlEYSvVi',
#  '69GGBxA162lTqCwzJG5jLp',
#  '7vk5e3vY1uw9plTHJAMwjN',
#  '4obzFoKoKRHIphyHzJ35G3',
#  '4npEfmQ6YuiwW1GpUmaq3F',
#  '31TPClRtHm23RisEBtV3X7',
#  '0z4gvV4rjIZ9wHck67ucSV',
#  '5H4yInM5zmHqpKIoMNAx4r',
#  '3AA28KZvwAUcZuOKwyblJQ',
#  '3tlXnStJ1fFhdScmQeLpuG',
#  '5Y3MV9DZ0d87NnVm56qSY1',
#  '3qiHUAX7zY4Qnjx8TNUzVx',
#  '7MiDcPa6UiV3In7lIM71IN',
#  '2cFrymmkijnjDg9SS92EPM',
#  '23fqKkggKUBHNkbKtXEls4',
#  '5XJDexmWFLWOkjOEjOVX3e',
#  '66ihevNkSYNzRAl44dx6jJ',
#  '14zUHaJZo1mnYtn6IBRaRP',
#  '12vb80Km0Ew53ABfJOepVz',
#  '33ScadVnbm2X8kkUqOkC6Z',
#  '757aE44tKEUQEqRuT6GnEB',
#  '1pQWsZQehhS4wavwh7Fnxd',
#  '6U3ybJ9UHNKEdsH7ktGBZ7',
#  '31W5EY0aAly4Qieq6OFu6I',
#  '1vCWHaC5f2uS3yhpwWbIA6',
#  '5LHRHt1k9lMyONurDHEdrp',
#  '1wZtkThiXbVNtj6hee6dz9',
#  '7rkW85dBwwrJtlHRDkJDAC',
#  '4PULA4EFzYTrxYvOVlwpiQ',
#  '2cPqdH7XMvwaBJEVjheH8g',
#  '2C6i0I5RiGzDKN9IAF8reh',
#  '1LIuN7ov1IBQDdLsU83ojl',
#  '1ZwdS5xdxEREPySFridCfh',
#  '1KCSPY1glIKqW2TotWuXOR',
#  '3Isy6kedDrgPYoTS1dazA9',
#  '4GNC7GD6oZMSxPGyXy4MNB',
#  '5fMUXHkw8R8eOP2RNVYEZX',
#  '0NGAZxHanS9e0iNHpR8f2W',
#  '3IW7ScrzXmPvZhB27hmfgy',
#  '0oOet2f43PA68X5RxKobEy',
#  '6fOMl44jA4Sp5b9PpYCkzz',
#  '7cYEt1pqMgXJdq00hAwVpT',
#  '2jku7tDXc6XoB6MO2hFuqg',
#  '0iEtIxbK0KxaSlF7G42ZOp',
#  '45TgXXqMDdF8BkjA83OM7z',
#  '2dIgFjalVxs4ThymZ67YCE',
#  '47mIJdHORyRerp4os813jD',
#  '1mYsTxnqsietFxj1OgoGbG',
#  '7vXDAI8JwjW531ouMGbfcp',
#  '6wWVKhxIU2cEi0K81v7HvP',
#  '7oPftvlwr6VrsViSDV7fJY',
#  '3vQ0GE3mI0dAaxIMYe5g7z',
#  '0GM7qgcRCORpGnfcN2tCiB',
#  '1U1el3k54VvEUzo3ybLPlM',
#  '21451j1KhjAiaYKflxBjr1',
#  '4IWBUUAFIplrNtaOHcJPRM',
#  '0VRj0yCOv2FXJNP47XQnx5',
#  '20JZFwl6HVl6yg8a4H3ZqK',
#  '57LYzLEk2LcFghVwuWbcuS',
#  '6DPYiyq5kWVQS4RGwxzPC7',
#  '2feDdbD5araYcm6JhFHHw7',
#  '6Te49r3A6f5BiIgBRxH7FH',
#  '73sIBHcqh3Z3NyqHKZ7FOL',
#  '0lAWpj5szCSwM4rUMHYmrr',
#  '23zg3TcAtWQy7J6upgbUnj',
#  '3jK9MiCrA42lLAdMGUZpwa',
#  '5Rl15oVamLq7FbSb0NNBNy',
#  '2UZIAOlrnyZmyzt1nuXr9y',
#  '5SXuuuRpukkTvsLuUknva1',
#  '0Dvx6p8JDyzeOPGmaCIH1L',
#  '0X2BH1fck6amBIoJhDVmmJ',
#  '4Z8W4fKeB5YxbusRsdQVPb',
#  '4DdkRBBYG6Yk9Ka8tdJ9BW',
#  '1aS5tqEs9ci5P9KD9tZWa6',
#  '1Yj5Xey7kTwvZla8sqdsdE',
#  '4tm8CEdm4pkQsEh4jIr9Yp',
#  '2oQX8QiMXOyuqbcZEFsZfm',
#  '0vR2qb8m9WHeZ5ByCbimq2',
#  '5JZ7CnR6gTvEMKX4g70Amv',
#  '4jogXSSvlyMkODGSZ2wc2P',
#  '2EMAnMvWE2eb56ToJVfCWs',
#  '1gW6pz5n1aK249L0GvfQCC',
#  '1bfl0AU8SqmLkElptOprhC',
#  '5gqmbbfjcikQBzPB5Hv13I',
#  '4yxLYO2imECxGYTTV7RQKb',
#  '5n9bMYfz9qss2VOW89EVs2',
#  '0XeEobZplHxzM9QzFQWLiR',
#  '3tJoFztHeIJkJWMrx0td2f',
#  '45dkTj5sMRSjrmBSBeiHym',
#  '75i9GaW2MJUgt4BkdUnuUY',
#  '5H1nN1SzW0qNeUEZvuXjAj',
#  '6ydoSd3N2mwgwBHtF6K7eX',
#  '2jSGzJw0ebJLu7OLVSOcBP',
#  '0jdNdfi4vAuVi7a6cPDFBM',
#  '6OBGbSaBUvQtk9wpQfDbOE',
#  '2QsynagSdAqZj3U9HgDzjD',
#  '4Gso3d4CscCijv0lmajZWs',
#  '4Ga1P7PMIsmqEZqhYZQgDo',
#  '0c173mlxpT3dSFRgMO8XPh',
#  '7gJN8W0589FisSYJS17K54',
#  '59jlthNnbmim5l9tmNA7se',
#  '4EPJlUEBy49EX1wuFOvtjK',
#  '21E3waRsmPlU7jZsS13rcj',
#  '13y7CgLHjMVRMDqxdx0Xdo',
#  '0oSGxfWSnnOXhD2fKuz2Gy',
#  '2txHhyCwHjUEpJjWrEyqyX',
#  '768O5GliF0bqscyghggrbE',
#  '58lV9VcRSjABbAbfWS6skp',
#  '2hejA1Dkf8v8R0koF44FvW',
#  '25uiPmTg16RbhZWAqwLBy5',
#  '3e7awlrlDSwF3iM0WBjGMp',
#  '0ys2OFYzWYB5hRDLCsBqxt',
#  '25XJqeReVV38w0tR04GGBd',
#  '5me0Irg2ANcsgc93uaYrpb',
#  '0C0XlULifJtAgn6ZNCW2eu',
#  '2uFUBdaVGtyMqckSeCl0Qj',
#  '4xRYI6VqpkE3UwrDrAZL8L',
#  '1qto4hHid1P71emI6Fd8xi',
#  '5ZS223C6JyBfXasXxrRqOk',
#  '51Blml2LZPmy7TTiAg47vQ',
#  '3t5xRXzsuZmMDkQzgOX35S',
#  '0JjPiLQNgAFaEkwoy56B1C',
#  '1zNqDE7qDGCsyzJwohVaoX',
#  '20wkVLutqVOYrc0kxFs7rA',
#  '4UXqAaa6dQYAk18Lv7PEgX',
#  '1z7b1Pr1rSlvWRzsW3HOrS',
#  '0ghlgldX5Dd6720Q3qFyQB',
#  '7okwEbXzyT2VffBmyQBWLz',
#  '687cZJR45JO7jhk1LHIbgq',
#  '23TFHmajVfBtlRx5MXqgoz',
#  '7jy3rLJdDQY21OgRLCZ9sD',
#  '1Ffb6ejR6Fe5IamqA5oRUF',
#  '0hEurMDQu99nJRq8pTxO14',
#  '0jnsk9HBra6NMjO2oANoPY',
#  '7eLcDZDYHXZCebtQmVFL25',
#  '1zNqQNIdeOUZHb8zbZRFMX',
#  '4f7KfxeHq9BiylGmyXepGt',
#  '7f5Zgnp2spUuuzKplmRkt7',
#  '6oMuImdp5ZcFhWP0ESe6mG',
#  '46pWGuE3dSwY3bMMXGBvVS',
#  '6tbjWDEIzxoDsBA1FuhfPW',
#  '540vIaP2JwjQb9dm3aArA4',
#  '5y2Xq6xcjJb2jVM54GHK3t',
#  '1sBkRIssrMs1AbVkOJbc7a',
#  '3aQeKQSyrW4qWr35idm0cy',
#  '1l7ZsJRRS8wlW3WfJfPfNS',
#  '3DiDSECUqqY1AuBP8qtaIa',
#  '6EPlBSH2RSiettczlz7ihV',
#  '7FBcuc1gsnv6Y1nwFtNRCb',
#  '22bE4uQ6baNwSHPVcDxLCe',
#  '3E6xrwgnVfYCrCs0ePERDz',
#  '5CiGnKThu5ctn9pBxv7DGa',
#  '4PzYKhC14sTJNEr0dzoo0d',
#  '360IAlyVv4PCEVjgyMZrxK',
#  '2W6WP4pHQTFlbr2z9S4n54',
#  '6FBDaR13swtiWwGhX1WQsP',
#  '6s22t5Y3prQHyaHWUN1R1C',
#  '0ErzCpIMyLcjPiwT4elrtZ',
#  '163tK9Wjr9P9DmM0AVK7lm',
#  '2Z0lRIqr997lIUiPtrpKCr',
#  '17lzZA2AlOHwCwFALHttmp',
#  '4PPoI9LuYeFX8V674Z1R6l',
#  '3tVQdUvClmAT7URs9V3rsp',
#  '7qjJw7ZM2ekDSahLXPjIlN',
#  '3oSJ7TBVCWMDMiYjXNiCKE',
#  '6sq1yF0OZEWA4xoXVKW1L9',
#  '5xYNmNkaWRqu3e5F4UXME8',
#  '0KPX4Ucy9dk82uj4GpKesn',
#  '2QWIScpFDNxmS6ZEMIUvgm',
#  '2kxP07DLgs4xlWz8YHlvfh',
#  '4iHNK0tOyZPYnBU7nGAgpQ',
#  '60d24wfXkVzDSfLS6hyCjZ',
#  '6cEuCEZu7PAE9ZSzLLc2oQ',
#  '6zFYqv1mOsgBRQbae3JJ9e',
#  '7j6DKwmjbxvpQO8h914uEz',
#  '3WGpXCj9YhhfX11TToZcXP',
#  '43BxCL6t4c73BQnIJtry5v',
#  '5IH6FPUwQTxPSXurCrcIov',
#  '3qvcCP2J0fWi0m0uQDUf6r',
#  '0h1zs4CTlU9D2QtgPxptUD',
#  '07PdYoE4jVRF6Ut40GgVSP',
#  '4YLtscXsxbVgi031ovDDdh',
#  '6deZN1bslXzeGvOLaLMOIF',
#  '0p4nmQO2msCgU4IF37Wi3j',
#  '5ZsFI1h6hIdQRw2ti0hz81',
#  '6LEG9Ld1aLImEFEVHdWNSB',
#  '3mIj9lX2MWuHmhNCA7LSCW',
#  '4wLXwxDeWQ8mtUIRPxGiD6',
#  '0cGUm45nv7Z6M6qdXYQGTX',
#  '6vXTefBL93Dj5IqAWq6OTv',
#  '3MHaV05u0io8fQbZ2XPtlC',
#  '1GKIlPFdcewHtpDVCQ8zmJ',
#  '6LqNN22kT3074XbTVUrhzX',
#  '3JhNCzhSMTxs9WLGJJxWOY',
#  '3QSQFmccmX81fWCUSPTS7y',
#  '5rGrDvrLOV2VV8SCFVGWlj',
#  '0BvkDsjIUla7X0k6CSWh1I',
#  '1h6Cn3P4NGzXbaXidqURXs',
#  '51DevdOxIJin6DB1FXJpD1',
#  '0elWFr7TW8piilVRYJUe4P',
#  '1Ts9of7VPZElwPQnqnDSfW',
#  '6icQOAFXDZKsumw3YXyusw',
#  '7qG3b048QCHVRO5Pv1T5lw',
#  '3rWZHrfrsPBxVy692yAIxF',
#  '0BHm7qbh3ENxvXzkQAG7MP',
#  '1Xylc3o4UrD53lo9CvFvVg',
#  '1GDbiv3spRmZ1XdM1jQbT7',
#  '6w9ToX5slZ4uIdmD17hJ3c',
#  '3b8QkneNDz4JHKKKlLgYZg',
#  '6Ip8FS7vWT1uKkJSweANQK',
#  '2FXC3k01G6Gw61bmprjgqS',
#  '4AVFqumd2ogHFlRbKIjp1t',
#  '3ipn9JLAPI5GUEo4y4jcoi',
#  '0epOFNiUfyON9EYx7Tpr6V',
#  '7gOdHgIoIKoe4i9Tta6qdD',
#  '0rjms710nwQTdrQheXHJfz',
#  '5xSx2FM8mQnrfgM1QsHniB',
#  '4m6ubhNsdwF4psNf3R8kwR',
#  '3RtNN1VnooWEn3KQk03DUL',
#  '4NJhFmfw43RLBLjQvxDuRS',
#  '6DgP9otnZw5z6daOntINxp',
#  '6MDME20pz9RveH9rEXvrOM',
#  '0u6GtibW46tFX7koQ6uNJZ',
#  '3l0CmX0FuQjFxr8SK7Vqag',
#  '7nDsS0l5ZAzMedVRKPP8F1',
#  '0UWZUmn7sybxMCqrw9tGa7',
#  '2T1aUibqR2QC2sINIDQOAK',
#  '7Lmrb6KcIzfkmgbtokjsAL',
#  '2UwqpfQtNuhBwviIC0f2ie',
#  '3LKXWvXFWrkwUzJWxzwVpW',
#  '4LEiUm1SRbFMgfqnQTwUbQ',
#  '2DlGxzQSjYe5N6G9nkYghR',
#  '2qxJFvFYMEDqd7ui6kSAcq',
#  '5nP8x4uEFjAAmDzwOEc9b8',
#  '2rhFzFmezpnW82MNqEKVry',
#  '0xRXCcSX89eobfrshSVdyu',
#  '2x7PC78TmgqpEIjaGAZ0Oz',
#  '6ASri4ePR7RlsvIQgWPJpS',
#  '20sxb77xiYeusSH8cVdatc',
#  '1tqysapcCh1lWEAc9dIFpa',
#  '2WzaAvm2bBCf4pEhyuDgCY',
#  '7Ey4PD4MYsKc5I2dolUwbH',
#  '7EQ0qTo7fWT7DPxmxtSYEc',
#  '4V8Sr092TqfHkfAA5fXXqG',
#  '3hteYQFiMFbJY7wS0xDymP',
#  '3CDoRporvSjdzTrm99a3gi',
#  '5he5w2lnU9x7JFhnwcekXX',
#  '4lxfqrEsLX6N1N4OCSkILp',
#  '3Y7RZ31TRPVadSFVy1o8os',
#  '6n28c9qs9hNGriNa72b26u',
#  '0eHQ9o50hj6ZDNBt6Ys1sD',
#  '2fMqTqiTxUDlmcOEPaQSsx',
#  '4NHQUGzhtTLFvgF5SZesLK',
#  '164Uj4eKjl6zTBKfJLFKKK',
#  '6QtgPSJPSzcnn7dPZ4VINp',
#  '0b1sIQumIAsNbqAoIClSpy',
#  '4IVAbR2w4JJNJDDRFP3E83',
#  '5LfGQac0EIXyAN8aUwmNAQ',
#  '1LZEQNv7sE11VDY3SdxQeN',
#  '10exVja0key0uqUkk6LJRT',
#  '02kJSzxNuaWGqwubyUba0Z',
#  '4axKuDPr6WKcDCyh8vueTY',
#  '1HBjj22wzbscIZ9sEb5dyf',
#  '1TtXnWcUs0FCkaZDPGYHdf',
#  '0YC192cP3KPCRWx8zr8MfZ',
#  '5t28BP42x2axFnqOOMg3CM',
#  '7FsRH5bw8iWpSbMX1G7xf1',
#  '2HPaUgqeutzr3jx5a9WyDV',
#  '4Q6nIcaBED8qUel8bBx6Cr',
#  '3GBPw9NK25X1Wt2OUvOwY3',
#  '1Oa0bMld0A3u5OTYfMzp5h',
#  '67MNhiAICFY6Pwc2YxCO0K',
#  '4bw2Am3p9ji3mYsXNXtQcd',
#  '6XpaIBNiVzIetEPCWDvAFP',
#  '5Y5TRrQiqgUO4S36tzjIRZ',
#  '5TYxZTjIPqKM8K8NuP9woO',
#  '0A0FS04o6zMoto8OKPsDwY',
#  '3pc0bOVB5whxmD50W79wwO',
#  '3gBKY0y3dFFVRqicLnVZYz',
#  '1r1uxoy19fzMxunt3ONAkG',
#  '5NUPPRjsbXHNyVDrUESYeh',
#  '1anyVhU62p31KFi8MEzkbf',
#  '3CJKkU0XuElRT1z8rEtIYg',
#  '2ae6PxICSOZHvjqiCcgon8',
#  '3hYtANQYrE6pd2PbtEyTIy',
#  '2YOYua8FpudSEiB9s88IgQ',
#  '1moxjboGR7GNWYIMWsRjgG',
#  '2ysnwxxNtSgbb9t1m2Ur4j',
#  '5aIqB5nVVvmFsvSdExz408',
#  '1Hsdzj7Dlq2I7tHP7501T4',
#  '0ZCO8oVkMj897cKgFH7fRW',
#  '5sUrlPAHlS9NEirDB8SEbF',
#  '64aJYyrXljOodnUG6jvhRD',
#  '6Q192DXotxtaysaqNPy5yR',
#  '6LnJKrtFnTEGdbWQ2riWCL',
#  '4JNo6Q5KdcRf1vtSX9mB0S',
#  '00XhexlJEXQstHimpZN910',
#  '2P5sC9cVZDToPxyomzF1UH',
#  '3FfvYsEGaIb52QPXhg4DcH',
#  '5rSXSAkZ67PYJSvpUpkOr7',
#  '4sTQVOfp9vEMCemLw50sbu',
#  '2pAWfrd7WFF3XhVt9GooDL',
#  '3NH8t45zOTqzlZgBvZRjvB',
#  '0Njy6yR9LykNKYg9yE23QN',
#  '0pcoadNMmvrUyab1RxWBoV',
#  '3YbOSxo85kla7RID8ugnW3',
#  '6JL8zeS1NmiOftqZTRgdTz',
#  '1G9G7WwrXka3Z1r7aIDjI7',
#  '70B80Lwx2sxti0M1Ng9e8K',
#  '1AL2GKpmRrKXkYIcASuRFa',
#  '3Xt3RrJMFv5SZkCfUE8C1J',
#  '5hdhHgpxyniooUiQVaPxQ0',
#  '0NbfKEOTQCcwd6o7wSDOHI',
#  '2oSONSC9zQ4UonDKnLqksx',
#  '2jw70GZXlAI8QzWeY2bgRc',
#  '3KV3p5EY4AvKxOlhGHORLg',
#  '77AiFEVeAVj2ORpC85QVJs',
#  '7bp2lSdh12wcA8LyB1srfJ',
#  '1mX1TWKpNxDSAH16LgDfiR',
#  '6kACVPfCOnqzgfEF5ryl0x',
#  '4az97MtWmBQ5Db3GfDh9j9',
#  '5f4QpKfy7ptCHwTqspnSJI',
#  '4bL2B6hmLlMWnUEZnorEtG',
#  '0SwO7SWeDHJijQ3XNS7xEE',
#  '3tJnB0s6c3oXPq1SCCavnd',
#  '1vqR17Iv8VFdzure1TAXEq',
#  '0my6Pg4I28dVcZLSpAkqhv',
#  '7guDJrEfX3qb6FEbdPA5qi',
#  '5v2WhpA59TJSdPh7LCx1lN',
#  '2MRBDr0crHWE5JwPceFncq',
#  '2gBjLmx6zQnFGQJCAQpRgw',
#  '2CCgb0KApjfQDuTppovpf8',
#  '4QFG9KrGWEbr6hNA58CAqE',
#  '4vhNDa5ycK0ST968ek7kRr',
#  '6fWVd57NKTalqvmjRd2t8Z',
#  '1Yfe3ONJlioHys7jwHdfVm',
#  '4mN0qcMxWX8oToqfDPM5yV',
#  '1WQBwwssN6r8DSjUlkyUGW',
#  '6AiX12wXdXFoGJ2vk8zBjy',
#  '0ZED1XzwlLHW4ZaG4lOT6m',
#  '0SfsnGyD8FpIN4U4WCkBZ5',
#  '74KM79TiuVKeVCqs8QtB0B',
#  '49tQo2QULno7gxHutgccqF',
#  '3eqjTLE0HfPfh78zjh6TqT',
#  '5bSfBBCxY8QAk4Pifveisz',
#  '1pgDilWYDWLoOgGjf1iHNu',
#  '2iDVt6mFbtbDEZG5ax0dTi',
#  '3SCOuAxngTC1yGjKMcIPEd',
#  '2wkoKEfS6dXwThbyTnZWFU',
#  '6x2LnllRG5uGarZMsD4iO8',
#  '0RESbWvOMyua0yuyVrztJ5',
#  '6W5uA6CNMf3hd2j4a2XWCx',
#  '1Mxqyy3pSjf8kZZL4QVxS0',
#  '3hv9jJF3adDNsBSIQDqcjp',
#  '3Z02hBLubJxuFJfhacLSDc',
#  '3RNrq3jvMZxD9ZyoOZbQOD',
#  '3nlpTZci9O5W8RsNoNH559',
#  '7bu3H8JO7d0UbMoVzbo70s',
#  '2wUjUUtkb5lvLKcGKsKqsR',
#  '1TA5sGRlKUJXBN4ZyJuDIX',
#  '2qk9voo8llSGYcZ6xrBzKx',
#  '45gHcnDnMC15sgx3VL7ROG',
#  '738wLrAtLtCtFOLvQBXOXp',
#  '2hR4h1Cao2ueuI7Cx9c7V8',
#  '1gPhS1zisyXr5dHTYZyiMe',
#  '6w3SkAHYPsQ1bxV7VDlG5y',
#  '3Mcii5XWf6E0lrY3Uky4cA',
#  '26T3LtbuGT1Fu9m0eRq5X3',
#  '4OBJLual30L7gRl5UkeRcT',
#  '35l9BRT7MXmM8bv2WDQiyB',
#  '1gJdf4Yybu4X5A2xYV3NMV',
#  '3AQRLZ9PuTAozP28Skbq8V',
#  '45eNHdiiabvmbp4erw26rg',
#  '6m6e7D2TnV0aYMllFFwMxu',
#  '108moq3rq6bm1M4Ypz0J02',
#  '6cK3NBO6uP7hh0oyuVELFl',
#  '15iVAtD3s3FsQR4w1v6M0P',
#  '165ZgPlLkK7bf5bDoFc6Sb',
#  '2ydZrTy8U3kOMOzx20s3dg',
#  '21WS9wngs9AqFckK7yYJPM',
#  '3BmGtnKgCSGYIUhmivXKWX',
#  '1dVygo6tRFXC8CSWURQJq2',
#  '3vUMXQ9kPnZAQkMkZZ7Hfh',
#  '19i93sA0D7yS9dYoVNBqAA',
#  '6CwfuxIqcltXDGjfZsMd9A',
#  '6WY7D3jk8zTrHtmkqqo5GI',
#  '7CUFPNi1TU8RowpnFRSsZV',
#  '0GgY7hjMoGDsX8ZDe2mwds',
#  '4nPxrGG7k7aEKmNLsfX4cd',
#  '0y59o4v8uw5crbN9M3JiL1',
#  '1GxkXlMwML1oSg5eLPiAz3',
#  '4fEkbug6kZzzJ8eYX6Kbbp',
#  '0qTZZWLzuD59Un5r1speHm',
#  '4GvEc3ANtPPjt1ZJllr5Zl',
#  '014WIDx7H4BRCHB1faiisK',
#  '056KMTw6IztdQjBmFfVyO3',
#  '1IueXOQyABrMOprrzwQJWN',
#  '487N2T9nIPEHrlTZLL3SQs',
#  '16kOCiqZ1auY4sokSeZuKf',
#  '5M9Bb4adKAgrOFOhc05Y50',
#  '5xd2Tg7Zo8755eCy8Gxkp8',
#  '5gCRApTajqwbnHHPbr2Fpi',
#  '7sfl4Xt5KmfyDs2T3SVSMK',
#  '3utZ2yeQk0Z3BCOBWP7Vlu',
#  '4J13m9IZh03PEhoxAxRhXO',
#  '4S9EykWXhStSc15wEx8QFK',
#  '3jOstUTkEu2JkjvRdBA5Gu',
#  '7y97mc3bZRFXzT2szRM4L4',
#  '4bthk9UfsYUYdcFyqxmSUU',
#  '4Ly0KABsxlx4fNj63zJTrF',
#  '5ENS85nZShljwNgg4wFD7D',
#  '3gIRvgZssIb9aiirIg0nI3',
#  '5e4Dhzv426EvQe3aDb64jL',
#  '0ONHkAv9pCAFxb0zJwDNTy',
#  '47MpMsUfWtgyIIBEFOr4FE',
#  '7slfeZO9LsJbWgpkIoXBUJ',
#  '5CCwRZC6euC8Odo6y9X8jr',
#  '4qXC0i02bSFstECuXP2ZpL',
#  '2W8yFh0Ga6Yf3jiayVxwkE',
#  '6MPCFvOQv5cIGfw3jODMF0',
#  '14CHVeJGrR5xgUGQFV5BVM',
#  '3MdXrJWsbVzdn6fe5JYkSQ',
#  '6yJCxee7QumYr820xdIsjo',
#  '048LktY5zMnakWq7PTtFrz',
#  '4TK1gDgb7QKoPFlzRrBRgR',
#  '20gsENnposVs2I4rQ5kvrf',
#  '76dRoxKtDwYkgCQePok9cU',
#  '1cNDP5yjU5vjeR8qMf4grg',
#  '5AZuEF0feCXMkUCwQiQlW7',
#  '61JrslREXq98hurYL2hYoc',
#  '2E6AK3UPEGCvjnzuygCh2h',
#  '6PH3FLQAxtqYy46Zv08bpV',
#  '5KNNVgR6LBIABRIomyCwKJ',
#  '1WgXqy2Dd70QQOU7Ay074N',
#  '4MoAOfV4ROWofLG3a3hhBN',
#  '6nS5roXSAGhTGr34W6n7Et',
#  '68YeXpLt3jB7JHQS5ZjMGo',
#  '4LAFtDzlQM89xov636hMVv',
#  '2KC9Qb60EaY0kW4eH68vr3',
#  '22WZ7M8sxp5THdruNY3gXt',
#  '5p7f24Rk5HkUZsaS3BLG5F',
#  '6Ad91Jof8Niiw0lGLLi3NW',
#  '2kXKa3aAFngGz2P4GjG5w2',
#  '5EvFsr3kj42KNv97ZEnqij',
#  '6vTqEFbTtTRJsuIpzZgjxi',
#  '2y8Jo9CKhJvtfeKOsYzRdT',
#  '4yiQZ8tQPux8cPriYMWUFP',
#  '7b79bQFziJFedJb75k6hFt',
#  '4FlG0V0jhLO4qGpayFOphj',
#  '4QQgXkCYTt3BlENzhyNETg',
#  '7f4ignuCJhLXfZ9giKT7rH',
#  '6ltzsmQQbmdoHHbLZ4ZN25',
#  '5YwzDz4RJfTiMHS4tdR5Lf',
#  '3UUJfRbrA2nTbcg4i0MOwu',
#  '39yVoqm6sYFvvqF1RciUVf',
#  '4sbXXFzEWJY2zsZjelerjX',
#  '6ZLTlhejhndI4Rh53vYhrY',
#  '6zLBxLdl60ekBLpawtT63I',
#  '2WBJQGf1bT1kxuoqziH5g4',
#  '09U6hmCerKcIJrixubiBjm',
#  '4D75GcNG95ebPtNvoNVXhz',
#  '1hcdI2N1023RvSwLzTtdsp',
#  '2gsggkzM5R49q6jpPvazou',
#  '1fctva4kpRbg2k3v7kwRuS',
#  '3m5qlPf2OkihLz3dRYnkPA',
#  '2NjfBq1NflQcKSeiDooVjY',
#  '5IcR3N7QB1j6KBL8eImZ8m',
#  '7gU9VyFRN3JWPJ5oHOil60',
#  '3CIIaeZuFYrAD6PRVyuO4U',
#  '762310PdDnwsDxAQxzQkfX',
#  '4ScCswdRlyA23odg9thgIO',
#  '3grHWM9bx2E9vwJCdlRv9O',
#  '085pc2PYOi8bGKj0PNjekA',
#  '7gZfnEnfiaHzxARJ2LeXrf',
#  '4fwuXg6XQHfdlOdmw36OHa',
#  '5VadK1havLhK1OpKYsXv9y',
#  '2ZRQcIgzPCVaT9XKhXZIzh',
#  '5yxyJsFanEAuwSM5kOuZKc',
#  '3eDT9fwXKuHWFvgZaaYC5v',
#  '5vngPClqofybhPERIqQMYd',
#  '4lDiJcOJ2GLCK6p9q5BgfK',
#  '1oH2B8tcHn4Gpl2bmmyd4A',
#  '3uL4UpqShC4p2x1dJutoRW',
#  '53A0W3U0s8diEn9RhXQhVz',
#  '4phGZZrJZRo4ElhRtViYdl',
#  '2sSGPbdZJkaSE2AbcGOACx',
#  '7z5WFjZAIYejWy0NI5lv4T',
#  '1z4g3DjTBBZKhvAroFlhOM',
#  '5IbEL2xjRtKsunfmsahLuO',
#  '5FxD8fkQZ6KcsSYupDVoSO',
#  '5M52tdBnJaKSvOpJGz8mfZ',
#  '5SulO4l40qDuV9zUGLZx7n',
#  '0CbeG1224FS58EUx4tPevZ',
#  '5BcAKTbp20cv7tC5VqPFoC',
#  '6USv9qhCn6zfxlBQIYJ9qs',
#  '3XxNRirzbjfLdDli06zMaB',
#  '4bYPcJP5jwMhSivRcqie2n',
#  '5j4HeCoUlzhfWtjAfM1acR',
#  '6AcOTCYBMvjKYy4zms0kaC',
#  '41X1TR6hrK8Q2ZCpp2EqCz',
#  '2VZNmg4vCnew4Pavo8zDdW',
#  '4boI7bJtmB1L3b1cuL75Zr',
#  '3oDbviiivRWhXwIE8hxkVV',
#  '6fxyWrfmjcbj5d12gXeiNV',
#  '28uJnu5EsrGml2tBd7y8ts',
#  '5ndkK3dpZLKtBklKjxNQwT',
#  '20qISvAhX20dpIbOOzGK3q',
#  '5YCc6xS5Gpj3EkaYGdjyNK',
#  '1on7ZQ2pvgeQF4vmIA09x5',
#  '4xFUf1FHVy696Q1JQZMTRj',
#  '2FKWNmZWDBZR4dE5KX4plR',
#  '0AqlFI0tz2DsEoJlKSIiT9',
#  '2AfmfGFbe0A0WsTYm0SDTx',
#  '2cnMpRsOVqtPMfq7YiFE6K',
#  '7iZtZyCzp3LItcw1wtPI3D',
#  '25UNJbwGZSQKvz5cPLWlv3',
#  '6IdtcAwaNVAggwd6sCKgTI',
#  '4IndUOBCZYZg61557iq2A9',
#  '4MVyzYMgTwdP7Z49wAZHx0',
#  '12GqGscKJx3aE4t07u7eVZ',
#  '0YinUQ50QDB7ZxSCLyQ40k',
#  '7F2utINZ6tSokSiZTQBE27',
#  '0PFtn5NtBbbUNbU9EAmIWF',
#  '4aXXDj9aZnlshx7mzj3W1N',
#  '3HiuzBlSW7pGDXlSFMhO2g',
#  '59wfkuBoNyhDMQGCljbUbA',
#  '3YCKuqpv9nCsIhJ2v8SMix',
#  '1hzfo8twXdOegF3xireCYs',
#  '6Mv8GjQa7LKUGCAqa9qqdb',
#  '4EzkuveR9pLvDVFNx6foYD',
#  '7uMh23xWiuR7zsNkuNcm2G',
#  '4mxWe1mtYIYfP040G38yvS',
#  '66lH4jAE7pqPlOlzUKbwA0',
#  '3FUY2gzHeIiaesXtOAdB7A',
#  '5B8ApeENp4bE4EE3LI8jK2',
#  '5QdEbQJ3ylBnc3gsIASAT5',
#  '3hq7WoPJsrRP0KMSLhUgRz',
#  '0haZhu4fFKt0Ag94kZDiz2',
#  '1ITjgqpqMDJlqZGAK3mlPQ',
#  '3ZHU5AKrUmIPnCFfr82QER',
#  '2kRfqPViCqYdSGhYSM9R0Q',
#  '3koiLjNrgRTNbOwViDipeA',
#  '4NUePmzDvCYqilXBFa91Hg',
#  '5eioJDe26lOqkAMbuhzZYs',
#  '2HcwFjNelS49kFbfvMxQYw',
#  '1vppDmG3i5sXf3DJzrK4T1',
#  '1cUpGtXcSQsovNYEZOQgOG',
#  '1MRiIeZbc0cRuxOafDUCtH',
#  '2wIVse2owClT7go1WT98tk',
#  '4DAcJXcjX0zlQAZAPAx4Zb',
#  '7DMveApC7UnC2NPfPvlHSU',
#  '3rfM2cGqF6DB0kUyytMkXx',
#  '40Yq4vzPs9VNUrIBG5Jr2i',
#  '19ra5tSw0tWufvUp8GotLo',
#  '4exLIFE8sISLr28sqG1qNX',
#  '7t0rwkOPGlDPEhaOcVtOt9',
#  '68KmkJeZGfwe1OUaivBa2L',
#  '6GRwwWAtmusrgAL5JF9Dfr',
#  '1tG7s7S4sq2eFFW0QZyLbm',
#  '3k68C6mNMJL6OaAdWeW2ZF',
#  '5yPzzu25VzEk8qrGTLIrE1',
#  '6P6GTRTigHBp8ZesNtpCKH',
#  '3hTffafUYLLgO4yuPAxb5U',
#  '3qnGvpP8Yth1AqSBMqON5x',
#  '2mpeljBig2IXLXRAFO9AAs',
#  '5dHt1vcEm9qb8fCyLcB3HL',
#  '7rOlQwf8OuFLFQp4aydjBt',
#  '7k73EtZwoPs516ZxE72KsO',
#  '3fZk3Gm5dN5v5yfYMQ04Bx',
#  '1sVmXkzX2ukc6QvasrDBES',
#  '2q9wk5fkeU2C9CgCKdh4AN',
#  '7gP3bB2nilZXLfPHJhMdvc',
#  '5JXhkyafynxCvxtov7C1PV',
#  '6nxWCVXbOlEVRexSbLsTer',
#  '5TvFfw1MgSntdU9A7yncyA',
#  '2GoeZ0qOTt6kjsWW4eA6LS',
#  '1cYhx7ZOhYoVmnDPb9KMwo',
#  '6T5tfhQCknKG4UnH90qGnz',
#  '1SJOL9HJ08YOn92lFcYf8a',
#  '5Wg2b4Mp42gicxEeDNawf7',
#  '4IG1SDlwgNKzqTmjBrvY3K',
#  '4rTv3Ejc7hKMtmoBOK1B4T',
#  '3ZxZ03fj3tXBZHZWzvaLSM',
#  '4ofCBoyEiGSePFAG500xev',
#  '6sFIWsNpZYqfjUpaCgueju',
#  '2IUtwMti1OiT3lkW6RubgH',
#  '00sCATpEvwH48ays7PlQFU',
#  '2p1fiYHYiXz9qi0JJyxBzN',
#  '0NIPkIjTV8mB795yEIiPYL',
#  '4ETSs924pXMzjIeD6E9b4u',
#  '6QrQ7OrISRYIfS5mtacaw2',
#  '0MIG6gMcQTSvFbKvUwK0id',
#  '6C1ohJrd5VydigQtaGy5Wa',
#  '0GF4shudTAFv8ak9eWdd4Y',
#  '2K5nCggbhSZ00YCYP5qkZS',
#  '31VFEohvhOUKrtAONEBhMG',
#  '2Tglaf8nvDzwSQnpSrjLHP',
#  '2LmcxBak1alK1bf7d1beTr',
#  '2F3KtUVtrt2GLjcl6pB4cz',
#  '5pBMkZNIlbGTH3hrsQJqAa',
#  '21mKp7DqtSNHhCAU2ugvUw',
#  '00me4Ke1LsvMxt5kydlMyU',
#  '44NX2ffIYHr6D4n7RaZF7A',
#  '1UTPBmNbXNTittyMJrNkvw',
#  '0V2oXYR7DtrZAEFeILRW2r',
#  '1KQJOTeIMbixtnSWY4sYs2',
#  '56SjZARoEvag3RoKWIb16j',
#  '75VKfyoBlkmrJFDqo1o2VY',
#  '4U7lXyKdSf1JbM1aXvsodC',
#  '5Zq7R5qmi58ByYyBQTlNuk',
#  '60uh2KYYSCqAgJNxcU4DA0',
#  '2qWK8K2Jfh67UqtwY8tCW6',
#  '0cc6vw3VN8YlIcvr1v7tBL',
#  '19k8AgwwTSxeaxkOuCQEJs',
#  '2jnIB6XdLvnJUeNTy5A0J2',
#  '4RddZ3iHvSpGV4dvATac9X',
#  '1fIJZfSmqQkuqfKNRmrS1V',
#  '5r3wPya2PpeTTsXsGhQU8O',
#  '5GnnSrwNCGyfAU4zuIytiS',
#  '4WZGDpNwrC0vNQyl9QzF7d',
#  '25u4wHJWxCA9vO0CzxAbK7',
#  '2y1VzMKAa5nmfXKtJL9jnj',
#  '4LXBc13z5EWsc5N32bLxfH',
#  '3lIU3RoZiHen1QXAQ3KQ9e',
#  '2IvkS5MXK0vPGnwyJsrEyV',
#  '3HqSLMAZ3g3d5poNaI7GOU',
#  '3SUT1jjM5hzZj9TLfLZGIP',
#  '5sWHDYs0csV6RS48xBl0tH',
#  '4e0nWw2r4BoQSKPQ2zpU13',
#  '2TcGJdSOiOvITBzhvfX8XB',
#  '5a2EaR3hamoenG9rDuVn8j',
#  '7zxFc10N9BP2lg73b8cwZ0',
#  '7cmuxPnXRJxwuYDHfbD8Eu',
#  '6bmlMHgSheBauioMgKv2tn',
#  '4Yttlv9ndGjCDCVLqM7ACq',
#  '5SHxzwjek1Pipl1Yk11UHv',
#  '7H55rcKCfwqkyDFH9wpKM6',
#  '58wXmynHaAWI5hwlPZP3qL',
#  '4YYxffPVDFe9XoqqbRW6Bq',
#  '0VKh7CQDi9MkUvaBMoK1V0',
#  '3hBQ4zniNdQf1cqqo6hzuW',
#  '5LeiVcEnsZcwc133TUhJNW',
#  '3Apb2lGmGJaBmr0TTBJvIZ',
#  '55fhWPvDiMpLnE4ZzNXZyW',
#  '2PJEagPIxaBugeMjIyKVXF',
#  '6PAt558ZEZl0DmdXlnjMgD',
#  '1CoZyIx7UvdxT5c8UkMzHd',
#  '6roFdX1y5BYSbp60OTJWMd',
#  '41QLxRXlc2NwfJZkHGHKid',
#  '1EXjXQpDx2pROygh8zvHs4',
#  '2SrSdSvpminqmStGELCSNd',
#  '1YfEcTuGvBQ8xSD1f53UnK',
#  '0SCbttzoZTnLFebDYmAWCm',
#  '5tQMB0cuNXdCtzovGt55uD',
#  '3gd8FJtBJtkRxdfbTu19U2',
#  '2VSHKHBTiXWplO8lxcnUC9',
#  '5zctI4wO9XSKS8XwcnqEHk',
#  '77kULmXAQ6vWer7IIHdGzI',
#  '4IC2X34tZmHG3VfTbpzvwL',
#  '3lY9Fxceu60W1rbon7PkuF',
#  '5nGIFgo0shDenQYSE0Sn7c',
#  '1pf0MPKfKdvS8J779mS1Ay',
#  '0H39MdGGX6dbnnQPt6NQkZ',
#  '1JbemQ1fPt2YmSLjAFhPBv',
#  '2Mu5NfyYm8n5iTomuKAEHl',
#  '0rZRTXEmmPmx6gt92tBqIc',
#  '43DRDu6nLSeIedZ7T1A616',
#  '2RQXRUsr4IW1f3mKyKsy4B',
#  '2wOqMjp9TyABvtHdOSOTUS',
#  '4VmEWwd8y9MCLwexFMdpwt',
#  '7yntSJ6uojO3z6GFUVwhAW',
#  '4K6blSRoklNdpw4mzLxwfn',
#  '5L1lO4eRHmJ7a0Q6csE5cT',
#  '74ASZWbe4lXaubB36ztrGX',
#  '0Upxnyh9nIUNSOmNE8WF4R',
#  '5rkVyNGXEgeUqKkB5ccK83',
#  '3JSSjGYcIkgsrz7892CelT',
#  '0rL4uL3xfYOt2p7NHhS8qr',
#  '3nFB4eMP5gdqee2eQb8nZb',
#  '69UypehHabb68utzfjAVlV',
#  '1etNnR2SdlelBQAICa2Q5m',
#  '5qa31A9HySw3T7MKWI9bGg',
#  '2gRP1Ezbtj3qrERnd0XasU',
#  '0EdvGhlC1FkGItLOWQzG4J',
#  '29aw5YCdIw2FEXYyAJZI8l',
#  '09UmIX92EUH9hAK4bxvHx6',
#  '0ZUvK7zGdXLd78mQr3t1Tw',
#  '0Sadg1vgvaPqGTOjxu0N6c',
#  '1pi7nGhOM7PTHR5YEgXVGq',
#  '2CmaKO2zEGJ1NWpS1yfVGz',
#  '6k8mwkKJKKjBILo7ypBspl',
#  '3wOsYKZM0zcKNasi3I7fP4',
#  '78rUTD7y6Cy67W1RVzYs7t',
#  '7keGfmQR4X5w0two1xKZ7d',
#  '1Db5GsIoVWYktPoD2nnPZZ',
#  '4puAp107dCehraE47QXVQX',
#  '6GMYJwaziB4ekv1Y6wCDWS',
#  '0u2FHSq3ln94y5Q57xazwf',
#  '0LX2VNf5w4iOHW1yyIqb74',
#  '1fUSLFr4WUBx7joEcGwpvG',
#  '6RdcIWVKYYzNzjQRd3oyHS',
#  '4Xi6LSfFqv26XgP9NKN26U',
#  '3a1tBryiczPAZpgoZN9Rzg',
#  '54R6Y0I7jGUCveDTtI21nb',
#  '3OLGltG8UPIea8sA4w0yg0',
#  '5F1aAS1duwlzExnPs3l2Xe',
#  '3yDIp0kaq9EFKe07X1X2rz',
#  '28DdkLhrzQNizZ0ExQpyku',
#  '0vdcZzmneH0nK9CYFHQBjk',
#  '2auC28zjQyVTsiZKNgPRGs',
#  '49EE6lVLgU8sp7dFgPshgM',
#  '37M5pPGs6V1fchFJSgCguX',
#  '0vLuOi2k62sHujIfplInlK',
#  '0Yg29FX1M4ayqjXs0ttZFq',
#  '2jzc5TC5TVFLXQlBNiIUzE',
#  '7uIbLdzzSEqnX0Pkrb56cR',
#  '03Yb3iBy9GCifXiATEFcit',
#  '5KKpBU5eC2tJDzf0wmlRp2',
#  '1MIVXf74SZHmTIp4V4paH4',
#  '5ja9cfKWW8Zj9aloyK8WuY',
#  '4nXOZlYoAD67hF9aUEncMY',
#  '3ghRXw2nUEH2THaL82hw8R',
#  '4BxCuXFJrSWGi1KHcVqaU4',
#  '1XkoF8ryArs86LZvFOkbyr',
#  '0T1CMVkqffHlqEk4BcAph1',
#  '32vWCbZh0xZ4o9gkz4PsEU',
#  '6uRJnvQ3f8whVnmeoecv5Z',
#  '2cWZOOzeOm4WmBJRnD5R7I',
#  '4BoRxUdrcgbbq1rxJvvhg9',
#  '7CQwac16i1W5ej8YpuL3dv',
#  '2kucQ9jQwuD8jWdtR9Ef38',
#  '5vBSrE1xujD2FXYRarbAXc',
#  '63MQldklfxkjYDoUE4Tppz',
#  '2ElMqlv5py0QFIVXUff627',
#  '41ESHLayJ5sDKjAOv6cMhe',
#  '6IE6z7DcZIT4Ml3Fh5Ivch',
#  '1Zkxm1dM3HI3QkTmxUEVQA',
#  '2vnB6tuQMaQpORiRdvXF9H',
#  '6sCbFbEjbYepqswM1vWjjs',
#  '67IN4cLJ7798gUapyZlmac',
#  '0I6yADrmeyvw66g7yjkqIF',
#  '3NPpFNZtSTHheNBaWC82rB',
#  '2Kx7MNY7cI1ENniW7vT30N',
#  '0Ty63ceoRnnJKVEYP0VQpk',
#  '6GI52t8N5F02MxU0g5U69P',
#  '2UMj7NCbuqy1yUZmiSYGjJ',
#  '29SeiO68HQHBs7pDdWOvvX',
#  '2KsP6tYLJlTBvSUxnwlVWa',
#  '2e4nwiX8ZCU09LGLOpeqTH',
#  '0U5RYP2HMdGv2GhicLhkOI',
#  '77tT1kLj6mCWtFNqiOmP9H',
#  '6ElqtIfQsAkEYypgfJIjeK',
#  '4frXpPxQQZwbCu3eTGnZEw',
#  '7HkdQ0gt53LP4zmHsL0nap',
#  '5U5wYVqrbD6J8SK4kNhau4',
#  '0CEFCo8288kQU7mJi25s6E',
#  '2q3GG88dVwuQPF4FmySr9I',
#  '28ExwzUQsvgJooOI0X1mr3',
#  '73jBynjsVtofjRpdpRAJGk',
#  '3PyJHH2wyfQK3WZrk9rpmP',
#  '6Dd3NScHWwnW6obMFbl1BH',
#  '2urF8dgLVfDjunO0pcHUEe',
#  '2SHhfs4BiDxGQ3oxqf0UHY',
#  '2mVVjNmdjXZZDvhgQWiakk',
#  '2IDLDx25HU1nQMKde4n61a',
#  '0VZrPa7mWAYXH4CwmYk8Km',
#  '5gs4Sm2WQUkcGeikMcVHbh',
#  '2kCO8LXN1usaOPL3iEE28I',
#  '7d3WFRME3vBY2cgoP38RDo',
#  '2iojnBLj0qIMiKPvVhLnsH',
#  '5Lv2GUVwqmQBPwrTrxucE5',
#  '0rZp7G3gIH6WkyeXbrZnGi',
#  '5ncITNKBT3RMa1U2NsuE7V',
#  '3Uobr6LgQpBbk6k4QGAb3V',
#  '1Y8cdNmUJH7yBTd9yOvr5i',
#  '5gOJTI4TusSENizxhcG7jB',
#  '6ARKr2ZoLf9TDoQiZarJMt',
#  '5wbf52LA6kcaboHSN6NEF1',
#  '5pVRwX5ZQR7hfJ18w8ZYkl',
#  '2DspEsT7UXGKd2VaaedgG4',
#  '7a0XAaPaK2aDSqa8p3QnC7',
#  '2IUl3m1H1EQ7QfNbNWvgru',
#  '4AKwRarlmsUlLjIwt38NLw',
#  '3tQzzidoPfVifoURnDfgmD',
#  '7pwufEBGfggjoI8twqlsmQ',
#  '1nzgtKYFckznkcVMR3Gg4z',
#  '7aBzpmFXB4WWpPl2F7RjBe',
#  '0TKFPt9w0AAEnhB9bd0pLy',
#  '3RqBeV12Tt7A8xH3zBDDUF',
#  '2oX42qP5ineK3hrhBECLmj',
#  '1HwM5zlC5qNWhJtM00yXzG',
#  '1W7FNibLa0O0b572tB2w7t',
#  '2cy1zPcrFcXAJTP0APWewL',
#  '7KMqksf0UMdyA0UCf4R3ux',
#  '0XK6kT7xcZAlcYrNjOgzJe',
#  '6zlR5ttMfMNmwf2lecU9Cc',
#  '3DCWeG2J1fZeu0Oe6i5Q6m',
#  '5g63iWaMJ2UrkZMkCC8dMi',
#  '4xnihxcoXWK3UqryOSnbw5',
#  '0gadJ2b9A4SKsB1RFkBb66',
#  '776Uo845nYHJpNaStv1Ds4',
#  '3yiEJ9SByXZMXTwaKdVFN4',
#  '5bWUlnPx9OYKsLiUJrhCA1',
#  '67nwj3Y5sZQLl72VNUHEYE',
#  '0eecdvMrqBftK0M1VKhaF4',
#  '6UBA15slIuadJ8h2lPRPos',
#  '6TLwD7HPWuiOzvXEa3oCNe',
#  '0ZHPrnImGh4re3TbSNkoZl',
#  '1gl0S9pS0Zw0qfa14rDD3D',
#  '5Pb27ujIyYb33zBqVysBkj',
#  '2nm38smINjms1LtczR0Cei',
#  '7xeM7V59cA1X8GKyKKQV87',
#  '1aw0Cdl1DIrtUrUA6fGbAR',
#  '3dRfiJ2650SZu6GbydcHNb',
#  '6AyATGg7mDgBlZ4N5uNog0',
#  '6CPZWzcKiOKkHn4L2XI4i2',
#  '5DUlefCLzVRzNWaNURTFpK',
#  '7fAKtXSdNInWAIf0jVUz65',
#  '0MoaBi6dSquXp6rrlqlF8R',
#  '4uoz4FUMvpeyGClFTTDBsD',
#  '46gyXjRIvN1NL1eCB8GBxo',
#  '3XHO7cRUPCLOr6jwp8vsx5',
#  '0TMvoNR0AIJV138mHY6jdE',
#  '1aWJsBQa67l72j1VT3D6Ow',
#  '3hN3iJMbbBmqBSAMx5veDa',
#  '3KedxarmBCyFBevnqQHy3P',
#  '2AZOALDIBORfbzKTuliwdJ',
#  '3Oim8XBPbznAa8Jj8QzNc8',
#  '22dFwJoRBV51ue5TGnC7Dt',
#  '0XKOBt59crntr7HQXXO8Yz',
#  '5nki7yRhxgM509M5ADlN1p',
#  '2QOIawHpSlOwXDvSqQ9YJR',
#  '1fux65HMCBvfJHqlBc4Nno',
#  '1a3fr7NdeBT4JlGj6YlbDL',
#  '1mfDfLsMxYcOOZkzBxvSVW',
#  '3tAICgiSR5PfYY4B8qsoAU',
#  '6h1s4i4XKIYv4ErDelLDN0',
#  '5ZqnEfVdEGmoPxtELhN7ai',
#  '0mA4dkNGiN4fqTBi2SLlAv',
#  '0ebNdVaOfp6N0oZ1guIxM8',
#  '2Dlvgi70UoJJicfKgoW5Vo',
#  '66TrUkUZ3RM29dqeDQRgyA',
#  '4upwdFMlZBmQ68jP9jPzjK',
#  '48HORs6F9P7IgdyKrk4MZC',
#  '0KKUc4amZyvswV2YL6WTar',
#  '4NiJW4q9ichVqL1aUsgGAN',
#  '2y246nnP9pQT0E6v3ZMMOO',
#  '4VIvfOurcf0vuLRxLkGnIG',
#  '6S0dmVVn4udvppDhZIWxCr',
#  ...]

# %%
# normalize: loudness, tempo, duration
# 4, 10, 11
# remove: type, id, uri, track_href, analysis_url
def get_median_audio_features_for_artists(artists):
    # map from id -> features
    id_to_features = defaultdict(dict)
    tracks = set()
    artists_to_ids = defaultdict(list)

    def get_top_track_ids(aid):
        nonlocal tracks, artists_to_ids
        resp = sp.artist_top_tracks(aid)
        ids = []
        for track in resp["tracks"]:
            id_ = track["id"]
            tracks.add(id_)
            artists_to_ids[aid].append(id_)
    
        return ids

    def get_audio_features(ids):
        nonlocal id_to_features
        resp = sp.audio_features(ids)
        for i in range(0, len(ids)):
            id_to_features[ids[i]] = resp[i]

    i = 0
    for a in artists:
        if i % 50 == 0: print("Artist #: ", i)
        get_top_track_ids(a)
        i += 1

    tracks = list(tracks)
    print(len(tracks)) # should be in the 29000 range
    chunk_size = 100
    for i in range(0, len(tracks), chunk_size):
        if (i % 1000) == 0: print("Feature analysis: ", i)
        track_chunk = tracks[i:i + chunk_size]
        get_audio_features(track_chunk)

    artist_to_features = defaultdict(list)
    for a in artists:
        features = []
        for id_ in artists_to_ids[a]:
            features_dic = id_to_features[id_]
            if features_dic is None: continue
            pop_keys = ["type", "id", "uri", "track_href", "analysis_url"]
            for p in pop_keys:
                if features_dic is None or p not in features_dic.keys(): continue
                features_dic.pop(p)
            features.append(list(features_dic.values()))
        arr = np.array(features)
        meds = np.median(arr, axis=0)
        artist_to_features[a] = meds.tolist()

    rows = [[key] + value for key, value in artist_to_features.items()]
    df = pd.DataFrame(rows)
    df = df.iloc[:, 1:].reset_index(drop=True)
    scaling_columns = [4, 11, 12]
    scaler = MinMaxScaler()
    df[scaling_columns] = scaler.fit_transform(df[scaling_columns])
    features_mat = df.to_numpy()

    np.save("components/Xaudiofeatures.npy", features_mat)
    return features_mat

Xaudiofeatures = get_median_audio_features_for_artists(artists)
# Out:
# Artist #:  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 67
#      64     np.save("components/Xaudiofeatures.npy", features_mat)
#      65     return features_mat
# ---> 67 Xaudiofeatures = get_median_audio_features_for_artists(artists)
#
# Cell In[6], line 30, in get_median_audio_features_for_artists(artists)
#      28 for a in artists:
#      29     if i % 50 == 0: print("Artist #: ", i)
# ---> 30     get_top_track_ids(a)
#      31     i += 1
#      33 tracks = list(tracks)
#
# Cell In[6], line 12, in get_median_audio_features_for_artists.<locals>.get_top_track_ids(aid)
#      10 def get_top_track_ids(aid):
#      11     nonlocal tracks, artists_to_ids
# ---> 12     resp = sp.artist_top_tracks(aid)
#      13     ids = []
#      14     for track in resp["tracks"]:
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/spotipy/client.py:451, in Spotify.artist_top_tracks(self, artist_id, country)
#     442 """ Get Spotify catalog information about an artist's top 10 tracks
#     443     by country.
#     444
#    (...)
#     447         - country - limit the response to one particular country.
#     448 """
#     450 trid = self._get_id("artist", artist_id)
# --> 451 return self._get("artists/" + trid + "/top-tracks", country=country)
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/spotipy/client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/spotipy/client.py:270, in Spotify._internal_call(self, method, url, payload, params)
#     266 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     267              method, url, args.get("params"), headers, args.get('data'))
#     269 try:
# --> 270     response = self._session.request(
#     271         method, url, headers=headers, proxies=self.proxies,
#     272         timeout=self.requests_timeout, **args
#     273     )
#     275     response.raise_for_status()
#     276     results = response.json()
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/urllib3/connectionpool.py:942, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     939     return response
#     941 response.drain_conn()
# --> 942 retries.sleep(response)
#     943 log.debug("Retry: %s", url)
#     944 return self.urlopen(
#     945     method,
#     946     url,
#    (...)
#     959     **response_kw,
#     960 )
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/urllib3/util/retry.py:359, in Retry.sleep(self, response)
#     350 """Sleep between retry attempts.
#     351
#     352 This method will respect a server's ``Retry-After`` response header
#    (...)
#     355 this method will return immediately.
#     356 """
#     358 if self.respect_retry_after_header and response:
# --> 359     slept = self.sleep_for_retry(response)
#     360     if slept:
#     361         return
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/urllib3/util/retry.py:338, in Retry.sleep_for_retry(self, response)
#     336 retry_after = self.get_retry_after(response)
#     337 if retry_after:
# --> 338     time.sleep(retry_after)
#     339     return True
#     341 return False
#
# KeyboardInterrupt:

# %%
Xartist = np.load("components/Xartist.npy")
X_artist_2_cols = Xartist[:, :2]

# %%
Xfeatures = np.concatenate((X_artist_2_cols, Xaudiofeatures), axis=1)

# %%
np.save("components/Xfeatures.npy", Xfeatures)
