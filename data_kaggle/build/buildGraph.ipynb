# %%
import pandas as pd
import numpy as np
import ast
import json
from sklearn.preprocessing import MinMaxScaler
import networkx as nx
import pickle
import matplotlib.pyplot as plt

# %%
edges = pd.read_csv('assets/edges.csv')
nodes = pd.read_csv('assets/nodes.csv')

# %%
edges
# Out:
#                           id_0                    id_1
# 0       76M2Ekj8bG8W7X2nbx2CpF  7sfl4Xt5KmfyDs2T3SVSMK
# 1       0hk4xVujcyOr6USD95wcWb  7Do8se3ZoaVqUt3woqqSrD
# 2       38jpuy3yt3QIxQ8Fn1HTeJ  4csQIMQm6vI2A2SCVDuM2z
# 3       6PvcxssrQ0QaJVaBWHD07l  6UCQYrcJ6wab6gnQ89OJFh
# 4       2R1QrQqWuw3IjoP5dXRFjt  4mk1ScvOUkuQzzCZpT6bc0
# ...                        ...                     ...
# 300381  0PK0Dx3s9et0Uf4XbdFpiW  6SmpksRq3jxeDZ7roKDb6F
# 300382  5hqRsNHDZH1jHzI9LgxFRZ  7KYseTkErcYMRvcIqacxUq
# 300383  0wjb0t7aYMuIwyuXnPOilh  2p1fiYHYiXz9qi0JJyxBzN
# 300384  3ciRvbBIVz9fBoPbtSYq4x  5einkgXXrjhfYCyac1FANB
# 300385  25uiPmTg16RbhZWAqwLBy5  3Xt3RrJMFv5SZkCfUE8C1J
#
# [300386 rows x 2 columns]

# %%
nodes = nodes.sort_values(by="popularity", ascending=False).drop("chart_hits", axis=1)
nodes['genres'] = nodes['genres'].apply(ast.literal_eval)
nodes = nodes[nodes['genres'].apply(lambda x: len(x) > 0)]
popularity = nodes["popularity"].to_list()

# %%
from collections import Counter
c = Counter(popularity)
c = sorted(c.items(), key= lambda x:-x[0])

brk = 3000
ct = 0
e = 0
for (k, v) in c:
    ct += v
    if ct >= brk:
        e = k
        print(k)
        break
# Out:
# 62

# %%
nodes = nodes.loc[nodes['popularity'] >= e]
nodes = nodes[~nodes['name'].duplicated(keep=False)]
nodes
# Out:
#                     spotify_id             name   followers  popularity  \
# 11203   4q3ewBCX7sLwd24euuV69X        Bad Bunny  55669387.0         100
# 18726   3TVXtAsR1Inumwj472S9r4            Drake  66852536.0          95
# 4646    06HL4z0CvFAxyc27GXpf02     Taylor Swift  58554324.0          94
# 13879   1Xyo4u8uXC1ZmMpatF05PJ       The Weeknd  49387909.0          93
# 19533   5K4W6rqBFWDnAN6FQUkS6x       Kanye West  18170307.0          91
# ...                        ...              ...         ...         ...
# 25121   7N0SBLJFpCyQSsv4MfRJ5d      Swarnalatha    772882.0          62
# 16640   6VxCmtR7S3yz4vnzsJqhSV         Sheppard    270154.0          62
# 7941    5xYkM2vMrE23taj6tl7qkm               Pk    654426.0          62
# 131164  6DJEUXZm0e2rAohdoZ5Voo    Black Thought    190045.0          62
# 115374  3TaTCYiv3QcamWjvRCcz6Q  Gavin Greenaway     10822.0          62
#
#                                                    genres
# 11203                            [reggaeton, trap latino]
# 18726   [canadian hip hop, canadian pop, hip hop, rap,...
# 4646                                                [pop]
# 13879      [canadian contemporary r&b, canadian pop, pop]
# 19533                                  [chicago rap, rap]
# ...                                                   ...
# 25121                                  [filmi, tamil pop]
# 16640   [australian indie, australian pop, folk-pop, n...
# 7941                            [funk carioca, trap funk]
# 131164  [alternative hip hop, boom bap, east coast hip...
# 115374                   [british soundtrack, soundtrack]
#
# [3305 rows x 5 columns]

# %%
genres = nodes["genres"].to_list()
all_genres = set()
for g in genres:
    l = set(g)
    all_genres = all_genres.union(l)

# %%
columns = ["id", "name", "followers", "popularity"] + list(all_genres)
genres_to_ind = {}

for i in range(len(columns)):
    genres_to_ind[columns[i]] = i

# %%
data = []

for ind, row in nodes.iterrows():
    r = [0] * len(columns)
    r[0] = (row["spotify_id"])
    r[1] = (row["name"])
    r[2] = (row["followers"])
    r[3] = (row["popularity"])
    for g in row["genres"]:
        r[genres_to_ind[g]] = 1

    data.append(r)

df = pd.DataFrame(data, columns=columns)
df = df.loc[:, df.sum() != 0]

# %% [markdown]
# ### feature

# %%
id_map = pd.Series(df.index, index=df["id"]).to_dict()
name_map = pd.Series(df.index, index=df["name"]).to_dict()

# %%
mat = df.iloc[:, 2:].reset_index(drop=True).to_numpy()

scaler = MinMaxScaler()
X = scaler.fit_transform(mat)

# %% [markdown]
# ### adjacency

# %%
n = len(X)
A = np.zeros((n, n))

ids = set(id_map.keys())

for _, row in edges.iterrows():
    u, v = row["id_0"], row["id_1"]

    if u in ids and v in ids and u != v:
        ui, vi = id_map[u], id_map[v]
        A[ui][vi] = 1
        A[vi][ui] = 1

# %% [markdown]
# ### making graph

# %%
ind_to_name = {v:k for (k, v) in name_map.items()}

# %%
G = nx.from_numpy_array(A)

# %% [markdown]
# ### remove degree zero nodes

# %%
empty = []
for node in G.nodes():
    if G.degree[node] == 0:
        empty.append(node)

ccs = [c for c in sorted(nx.connected_components(G), key=len, reverse=True)]

for cc in ccs[1:]:
    pcc = []
    for a in cc:
        pcc.append(ind_to_name[a])
        empty.append(a)
    print(pcc)
# Out:
# ['Einár', '23', 'Ballinciaga', 'Veronica Maggio', 'Victor Leksell', 'ADAAM', 'Hov1']
# ['İrem Derici', 'Kurtuluş Kuş', 'Mustafa Ceceli', 'Burak Bulut']
# ['System Of A Down', 'Wu-Tang Clan']
# ['Em Beihold', 'Stephen Sanchez']
# ['Freddie Dredd', 'Lil Darkie']
# ['Pastel Ghost', 'Mr.Kitty']
# ['Megadeth', 'Lamb of God']
# ['Enya', 'Howard Shore']
# ['Grover Washington, Jr.', 'Bill Withers']
# ['iamjakehill', 'Josh A']
# ['Los Acosta', 'Grupo Bryndis']
# ['Brooke Ligertwood', 'Hillsong UNITED']
# ['Egzod', 'Neoni']
# ['Aimyon', 'RADWIMPS']
# ['11:11 Music Group', 'creamy']
# ['Fiersa Besari', 'Feby Putri']
# ['Kep1er', 'LOONA']
# ['HA SUNG WOON', 'Punch']
# ['Skusta Clee', 'Flow G']
# ['Alice Cooper', 'Theory of a Deadman']
# ['Harry Styles']
# ['Arctic Monkeys']
# ['Die drei ???']
# ['Adele']
# ['Red Hot Chili Peppers']
# ['Twenty One Pilots']
# ['Cigarettes After Sex']
# ['Nirvana']
# ['Zach Bryan']
# ['ABBA']
# ['AC/DC']
# ['Kate Bush']
# ['Mitski']
# ['Fleetwood Mac']
# ["Guns N' Roses"]
# ['Slipknot']
# ['Pink Floyd']
# ['Melanie Martinez']
# ['Mac DeMarco']
# ['Lofi Fruits Music']
# ['Creedence Clearwater Revival']
# ['Ado']
# ['Ghost']
# ['The Lumineers']
# ['Muse']
# ['Chill Fruits Music']
# ['Deftones']
# ['Paramore']
# ['Bibi Blocksberg']
# ['girl in red']
# ['Led Zeppelin']
# ['ENHYPEN']
# ['Shiloh Dynasty']
# ['Bibi und Tina']
# ['IVE']
# ['Oasis']
# ['Eagles']
# ['The Smiths']
# ['Dire Straits']
# ['The Police']
# ['Iron Maiden']
# ['Three Days Grace']
# ['Journey']
# ['Pearl Jam']
# ['Avenged Sevenfold']
# ['Mother Mother']
# ['Jay Chou']
# ['Disturbed']
# ['Fujii Kaze']
# ['YOASOBI']
# ['Soda Stereo']
# ['aespa']
# ['KISS']
# ['Bo Burnham']
# ['Bailey Zimmerman']
# ['TV Girl']
# ['Sabaton']
# ['R.E.M.']
# ['Scorpions']
# ['White Noise Baby Sleep']
# ['Skillet']
# ['Interplanetary Criminal']
# ['Benson Boone']
# ['Die drei ??? Kids']
# ['The Walters']
# ['Rage Against The Machine']
# ['Beach House']
# ['Lauren Spencer Smith']
# ['Toby Fox']
# ['The Goo Goo Dolls']
# ['Simon & Garfunkel']
# ['Volbeat']
# ['Vacations']
# ['Armani White']
# ['The Clash']
# ['Beach Weather']
# ['Dayglow']
# ['Official HIGE DANdism']
# ['Mrs. GREEN APPLE']
# ['Sum 41']
# ['Pixies']
# ['Rise Against']
# ['Electric Light Orchestra']
# ['The White Stripes']
# ['Sufjan Stevens']
# ['The Black Keys']
# ['Cafuné']
# ['HOYO-MiX']
# ['TOOL']
# ['Queens of the Stone Age']
# ['King Gnu']
# ['White Noise for Babies']
# ['EXO']
# ['Djadja & Dinaz']
# ['LE SSERAFIM']
# ['Grupo Frontera']
# ['Alex G']
# ['Arthur Nery']
# ['Caifanes']
# ['dhruv']
# ["Adolescent's Orquesta"]
# ['Incubus']
# ['back number']
# ['Saucy Dog']
# ['UB40']
# ['Rainbow Kitten Surprise']
# ['Audioslave']
# ['Joe Hisaishi']
# ['Yuuri']
# ['STAYC']
# ['John Denver']
# ['Crystal Castles']
# ['Øneheart']
# ['Snow Patrol']
# ['Kool & The Gang']
# ['Survivor']
# ['Lauren Daigle']
# ['Dance Fruits Music']
# ['Of Monsters and Men']
# ['Lovejoy']
# ['Grupo Niche']
# ['Air Supply']
# ['Parker McCollum']
# ['Kenshi Yonezu']
# ['Godsmack']
# ['Amanda Seyfried']
# ['Legião Urbana']
# ['Ali Sethi']
# ['Dolu Kadehi Ters Tut']
# ['Madrigal']
# ['LiSA']
# ['Jimmy Eat World']
# ['Hugh Jackman']
# ['Simple Minds']
# ['Mareux']
# ['PXNDX']
# ['Big Time Rush']
# ['The Wiggles']
# ['PlayaPhonk']
# ['Liaze']
# ['Boston']
# ['Sticky Fingers']
# ['Stone Temple Pilots']
# ['Heroes Del Silencio']
# ['The Rare Occasions']
# ['Declan McKenna']
# ['The Backseat Lovers']
# ['Wham!']
# ['Stick Figure']
# ['Keisya Levronka']
# ['Simply Red']
# ['The Verve']
# ['Frankie Ruiz']
# ['Hiko']
# ['Duman']
# ['Fabio Asher']
# ['KÖFN']
# ['Hensonn']
# ['V']
# ['HIRAIDAI']
# ['Hoobastank']
# ['EDEN']
# ['N.W.A.']
# ['Creepy Nuts']
# ['Mimi Webb']
# ['Los Del Limit']
# ['Binomio de Oro de América']
# ['Patricio Rey y sus Redonditos de Ricota']
# ['El Cuarteto De Nos']
# ['The Kinks']
# ['ヨルシカ']
# ['Molotov']
# ['Eddie Santiago']
# ['NMIXX']
# ['Samuel Kim']
# ['Yüzyüzeyken Konuşuruz']
# ['Die Ärzte']
# ['IV Of Spades']
# ['BIGBANG']
# ['The Paper Kites']
# ['Vundabar']
# ['Rain Sounds']
# ['Sam Cooke']
# ['Our Last Night']
# ['Al James']
# ['Rick Astley']
# ['Savage Garden']
# ['Keung To']
# ['Nightwish']
# ['Ben E. King']
# ['Soegi Bornean']
# ['Deep Sleep Music Collective']
# ['Europe']
# ['Parcels']
# ['Jessie Murph']
# ['Anuv Jain']
# ['Macaroni Empitsu']
# ['Mavi Gri']
# ['Aaron Smith']
# ['The Outfield']
# ['Mr.Children']
# ['La Ley']
# ['NCT U']
# ['Vanessa Hudgens']
# ['Tani Yuuki']
# ['Yiruma']
# ['Men At Work']
# ['mor ve ötesi']
# ['framed']
# ['O Rappa']
# ['Johannes Brahms']
# ['Sheila On 7']
# ['Simge']
# ['Stone Sour']
# ['Makar']
# ['Rebzyyx']
# ['Neck Deep']
# ['Barry White']
# ['Suki Waterhouse']
# ['Ocean Sounds']
# ['Los Prisioneros']
# ['The Head And The Heart']
# ['Nate Smith']
# ['ROSÉ']
# ['Hollow Coves']
# ['DAY6']
# ['In Flames']
# ['grentperez']
# ['Vansire']
# ['Enjambre']
# ['awfultune']
# ['Boris Brejcha']
# ['Thin Lizzy']
# ['Parokya Ni Edgar']
# ['Saint Motel']
# ['Los Bunkers']
# ['Don McLean']
# ['Third Eye Blind']
# ['Modest Mouse']
# ['Slightly Stoopid']
# ['tana']
# ['Vierre Cloud']
# ['Vilma Palma e Vampiros']
# ['Los Rehenes']
# ['Mandy Moore']
# ['Wilbur Soot']
# ['Roar']
# ['Stereophonics']
# ['Last Child']
# ["Auli'i Cravalho"]
# ['Tobias Rahim']
# ['Leo Mattioli']
# ['Connor Price']
# ['Vierra']
# ['Molchat Doma']
# ['Catfish and the Bottlemen']
# ['Juicy Luicy']
# ['Eraserheads']
# ['La Factoria']
# ['4 Non Blondes']
# ['Polo & Pan']
# ['Exaltasamba']
# ['Ross Lynch']
# ['Wheatus']
# ['GOT7']
# ['Jordan Fisher']
# ['7 Minutoz']
# ['Denny Caknan']
# ['Karpe']
# ['Yann Tiersen']
# ['Robert Schumann']
# ['Nivel Codiciado']
# ['Mauro Castillo']
# ['JONY']
# ['Ace of Base']
# ['Ahmet Kaya']
# ['Alex Turner']
# ['Jack Stauber']
# ['Andmesh']
# ['Mabel Matiz']
# ['Pat Benatar']
# ['KC & The Sunshine Band']
# ['Los inquietos del vallenato']
# ['The Cinematic Orchestra']
# ['South Park Mexican']
# ['Yahritza Y Su Esencia']
# ['TWOPILOTS']
# ['t.A.T.u.']
# ['Ray LaMontagne']
# ['Aditya A']
# ['Nogizaka46']
# ['ZUTOMAYO']
# ['Die Toten Hosen']
# ['Noah']
# ['Nadin Amizah']
# ['DTF']
# ['Bridgit Mendler']
# ['Goldband']
# ['Dexys Midnight Runners']
# ['Shotgun Willy']
# ['Gnarls Barkley']
# ['NOBITA']
# ['Valley']
# ['Serdar Ortaç']
# ['Yiyo Sarante']
# ['Ebru Gündeş']
# ['SR']
# ['Alfie Templeman']
# ['Dreamcatcher']
# ['Joy Again']
# ['Julien Bam']
# ['THE BOYZ']
# ['Stevie Ray Vaughan']
# ['Fiji Blue']
# ['Josh Levi']
# ['Confetti']
# ['ASTN']
# ['Paul Partohap']
# ['Irene Cara']
# ['New West']
# ['Rafaga']
# ['Edvard Grieg']
# ['Prateek Kuhad']
# ['Dybbukk']
# ['I DONT KNOW HOW BUT THEY FOUND ME']
# ['Jessé Aguiar']
# ['Sixpence None The Richer']
# ['Sergei Rachmaninoff']
# ['Payung Teduh']
# ['Novelbright']
# ['La Renga']
# ['Los Farmerz']
# ['Spacey Jane']
# ['Bolaget']
# ['Iron & Wine']
# ['Blue Öyster Cult']
# ['Naomi Scott']
# ['Mitraz']
# ['Los Diablitos']
# ['David Kushner']
# ['Anthony Keyrouz']
# ['Yasin']
# ['Harnoor']
# ['İbrahim Tatlıses']
# ['Dr. Dog']
# ['Extreme']
# ['Pretenders']
# ['Rauf & Faik']
# ['Azahriah']
# ['Daughter']
# ['JayDaYoungan']
# ['Nivaldo Marques']
# ['Katrina & The Waves']
# ['REDZED']
# ['Janis Joplin']
# ['Edward Sharpe & The Magnetic Zeros']
# ['Beendo Z']
# ['maNga']
# ['Alceu Valença']
# ['Christine Baranski']
# ['Julio Jaramillo']
# ['THE DRIVER ERA']
# ['Hivi!']
# ['Funda Arar']

# %%
G.remove_nodes_from(empty)

# %%
A = nx.to_numpy_array(G)

# %%
np.save("components/A.npy", A)

# %%
nx.write_graphml(G, 'components/graph.graphml')

# %%
df = df.drop(empty, axis=0).reset_index(drop=True)

# %%
df.to_csv('components/nodes.csv')

id_map = pd.Series(df.index, index=df["id"]).to_dict()
name_map = pd.Series(df.index, index=df["name"]).to_dict()

with open("components/id_to_ind.json", "w") as file:
    json.dump(id_map, file, indent=2)

with open("components/name_to_ind.json", "w") as file:
    json.dump(name_map, file, indent=2)

ind_to_name = {v:k for (k, v) in name_map.items()}
ind_to_id = {v:k for (k, v) in id_map.items()}

with open("components/ind_to_id.json", "w") as file:
    json.dump(ind_to_id, file, indent=2)

with open("components/ind_to_name.json", "w") as file:
    json.dump(ind_to_name, file, indent=2)

mat = df.iloc[:, 2:].reset_index(drop=True).to_numpy()

scaler = MinMaxScaler()
X = scaler.fit_transform(mat)

np.save("components/X.npy", X)
