# %%
from util import *
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ### initialize spotipy

# %%
sp = get_client()

# %% [markdown]
# ### get artist matrix and indices
# - one hot array for each non-empty genre along w/ a scaled popularity and followers

# %%
artist_ids, decoded_genres = get_artists_and_genres(True)

# %%
artists_df = get_artists_df(sp, artist_ids, decoded_genres)
# Out:
# Adding:  Rionegro & Solimões
# Adding:  Antônio Carlos Jobim
# Adding:  Tori Kelly
# Adding:  Yiyo Sarante
# Adding:  Aditya A
# Adding:  IP Singh
# Adding:  BLOK3
# Adding:  Maverick City Music
# Adding:  Anar
# Adding:  AYLIVA
# Adding:  Old Jim
# Adding:  Dream, Ivory
# Adding:  Yann Tiersen
# Adding:  NDX A.K.A.
# Adding:  Switch Disco
# Adding:  Ari Abdul
# Adding:  ChiChi Peralta
# Adding:  Mandy Moore
# Adding:  Mert Demir
# Adding:  310babii
# Adding:  Big Thief
# Adding:  Drowning Pool
# Adding:  Uncle Kracker
# Adding:  Codiciado
# Adding:  Surf Mesa
# Adding:  Russ Millions
# Adding:  Rupert Holmes
# Adding:  Vegedream
# Adding:  Quality Control
# Adding:  Lit
# Adding:  Maninder Buttar
# Adding:  Stephanie Beatriz
# Adding:  BK
# Adding:  Tarcísio do Acordeon
# Adding:  Adriel Favela
# Adding:  Yoko Gold
# Adding:  Peter Bjorn and John
# Adding:  ThxSoMch
# Adding:  Pancho Barraza
# Adding:  Meryl Streep
# Adding:  Wings
# Adding:  Blue Öyster Cult
# Adding:  Marracash
# ...

# %%
artists_df.to_csv('assets/artists_df.csv', index=False)

# %%
X, id_map, name_map = get_map_and_numpy_array(artists_df)

# %%
artists_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2500 entries, 0 to 2499
# Columns: 1030 entries, id to
# dtypes: int64(1028), object(2)
# memory usage: 19.7+ MB

# %% [markdown]
# ### get adjacency matrix

# %%
artist_ids, decoded_genres = get_artists_and_genres(preloaded=True)

# %%
len(artist_ids)
# Out:
# 2476

# %%
# rm .cache

# %%
# sp = get_client()

# %%
# ids_to_name = {}
# with open('assets/id_to_ind.json', 'r') as file:
#     # ids_to_name = json.load(file)

# %%
# iterate over artists

# get albums and add them to a set, if in set, skip
# concurrently, dispatch lists of albums and iterate over their artists

# create permutations and add to numpy array

# %%
# # sp.artist_albums(artist_id=a0, limit=1000)
# def get_adjacency_matrix(sp, artist_ids, ids_to_name, limit=50):
#     n = len(artist_ids)
#     A = np.zeros((n, n))

#     albums, failed = set(), []

#     lock = threading.Lock()

#     def get_artist_albums(aid, limit=50):
#         nonlocal albums
#         inner, total, ind = set(), 1, 0
#         try:
#             while ind < total:
#                 resp = sp.artist_albums(artist_id=aid, album_type="single,appears_on,compilation,album", limit=limit)
#                 ind += limit
#                 total = max(total, resp["total"])
#                 for a in resp["items"]:
#                     inner.add(a["id"])
#             with lock:
#                 print(len(albums), len(inner))
#                 albums = albums.union(inner)
#         except BaseException as e:
#             with lock: 
#                 failed.append(aid)
#                 print(e)
        
#     threads = []
#     for a in artist_ids:
#         print(a)
#         thread = threading.Thread(target=get_artist_albums, args=(a,))
#         threads.append(thread)
#         thread.start()

#     for thread in threads:
#         thread.join()

#     # while failed:
#     #     time.sleep(30)
#     #     f = failed.pop()
#     #     get_artist_albums(f)

#     print(albums)
#     with open('base_ex/out.json', 'w') as file:
#         json.dump(list(albums), file, indent=2)

#     return A

# A = get_adjacency_matrix(sp, artist_ids[0:10], ids_to_name)

# %%
# A
