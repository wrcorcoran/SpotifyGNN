# %%
from util import *

# %%
artist_ids, decoded_genres = get_artists_and_genres(preloaded=True)
ids_to_ind, names_to_ind, ind_to_ids_names = get_name_id_map()
sp = get_client()

# %%
token = ""
resp = requests.get(f'https://api.spotify.com/v1/artists/{artist_ids[0]}', headers={"Authorization": f"Bearer {token}"})
print(resp.text)
# Out:
# Too many requests

# %%
sp.artist(artist_ids[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sp.artist(artist_ids[0])
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/spotipy/client.py:396, in Spotify.artist(self, artist_id)
#     389 """ returns a single artist given the artist's ID, URI or URL
#     390
#     391     Parameters:
#     392         - artist_id - an artist ID, URI or URL
#     393 """
#     395 trid = self._get_id("artist", artist_id)
# --> 396 return self._get("artists/" + trid)
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/spotipy/client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# ...

# %%
# resp = sp.artist_albums(
#             artist_id=artist_ids[0],
#             album_type="single,appears_on,compilation,album",
#             limit=50,
#         )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 resp = sp.artist_albums(
#       2             artist_id=artist_ids[0],
#       3             album_type="single,appears_on,compilation,album",
#       4             limit=50,
#       5         )
#
# File ~/opt/anaconda3/envs/spotify/lib/python3.10/site-packages/spotipy/client.py:433, in Spotify.artist_albums(self, artist_id, album_type, include_groups, country, limit, offset)
#     430     include_groups = include_groups or album_type
#     432 trid = self._get_id("artist", artist_id)
# --> 433 return self._get(
#     434     "artists/" + trid + "/albums",
#     435     include_groups=include_groups,
#     436     country=country,
#     437     limit=limit,
#     438     offset=offset,
#     439 )
#
# ...

# %%
A = get_adjacency_matrix(sp, [artist_ids[0]], ids_to_ind)
A_mat = np.array(A)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# starting  6qqNVTkY8uBg9cP3Jd7DAH
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 A = get_adjacency_matrix(sp, [artist_ids[0]], ids_to_ind)
#       2 A_mat = np.array(A)
#
# File ~/Projects/SpotifyGNN/data/util.py:264, in get_adjacency_matrix(sp, artists, ids_to_ind)
#     261     thread.start()
#     263 for thread in threads:
# ...

# %%
non_zero_indices = np.nonzero(A_mat)
print(len(non_zero_indices))
print(len(non_zero_indices) / (2500 * 2500))
# Out:
# Element at row 57, column 1886 is 1.0
# Element at row 57, column 1957 is 1.0
# Element at row 57, column 2056 is 1.0
# Element at row 57, column 2145 is 1.0
# Element at row 57, column 2254 is 1.0
# Element at row 57, column 2282 is 1.0
# Element at row 57, column 2331 is 1.0
# Element at row 57, column 2340 is 1.0
# Element at row 59, column 2250 is 1.0
# Element at row 64, column 2252 is 1.0
# Element at row 68, column 2254 is 1.0
# Element at row 142, column 667 is 1.0
# Element at row 147, column 1263 is 1.0
# Element at row 150, column 2254 is 1.0
# Element at row 151, column 2084 is 1.0
# Element at row 181, column 1332 is 1.0
# Element at row 195, column 592 is 1.0
# Element at row 195, column 1055 is 1.0
# Element at row 195, column 1313 is 1.0
# Element at row 195, column 2071 is 1.0
# Element at row 195, column 2251 is 1.0
# Element at row 213, column 738 is 1.0
# Element at row 213, column 850 is 1.0
# Element at row 213, column 1546 is 1.0
# ...
